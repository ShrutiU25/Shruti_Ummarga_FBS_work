# %%
import numpy as np

# %%
arr1 = np.array([[1,2],
                 [3,4]])

# %%
arr1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
arr1[ :,0]
# Out:
# array([1, 3])

# %%
arr1[ :,1]
# Out:
# array([2, 4])

# %%
arr2 = np.array([arr1[ :,0],
                 arr1[ :,1]])

# %%
arr2
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
arr1.T
#will give you transposed matrix
# Out:
# array([[1, 3],
#        [2, 4]])
