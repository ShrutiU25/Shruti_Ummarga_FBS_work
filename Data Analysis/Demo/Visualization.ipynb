# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Iris.csv')

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
#plt.plot(data['Sepal_Length'], data['Sepal_Width'])
plt.scatter(data['Sepal_Length'], data['Sepal_Width'])
#draw scatter plot

# %%
plt.hist(data['Sepal_Length'], edgecolor='black')
#draw histogram
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Histogram
# Histogram will be used on one single value and it show its dispersion

# %% [markdown]
# # Scatter Plot
# It will tell how two values are correlated

# %%
data = pd.read_csv('cars93.csv')

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
plt.scatter(data['Price'], data['MPG.city'])

# %%
plt.scatter(data['Model'], data['Type'])
#do not use scatter plot for string value

# %%
data['Type'].value_counts()
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
#plt.hist(data['Type'])
# Out:
# (array([21.,  0., 22.,  0., 16.,  0., 11.,  0., 14.,  9.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
data['Type'].value_counts()
x = data['Type'].value_counts().index
y = data['Type'].value_counts().values

# %%
plt.bar(x,y)
#plt.bar(types,counts)
#plt.xlabel('Types')
#plt.ylabel('Counts')
# Out:
# <BarContainer object of 6 artists>

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
result = data.groupby('Type')['Price'].mean()

# %%
plt.bar(result.index, result.values)
# Out:
# <BarContainer object of 6 artists>

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
#data.groupby('AirBags')['AirBags'].count()
result = data['AirBags'].value_counts()
#counting different airbags numbers

# %%
plt.bar(result.index, result.values)
# Out:
# <BarContainer object of 2 artists>

# %%
data = pd.read_excel('Salaries.xlsx')

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
data.shape
# Out:
# (1000, 13)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1000 non-null   int64
#  1   EmployeeName      1000 non-null   str
#  2   JobTitle          1000 non-null   str
#  3   BasePay           1000 non-null   float64
#  4   OvertimePay       1000 non-null   float64
#  5   OtherPay          1000 non-null   float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          1000 non-null   float64
#  8   TotalPayBenefits  1000 non-null   float64
#  9   Year              1000 non-null   int64
#  10  Notes             0 non-null      float64
#  11  Agency            1000 non-null   str
#  12  Status            0 non-null      float64
# dtypes: float64(8), int64(2), str(3)
# memory usage: 101.7 KB

# %%
data.isna().sum()
# Out:
# Id                     0
# EmployeeName           0
# JobTitle               0
# BasePay                0
# OvertimePay            0
# OtherPay               0
# Benefits            1000
# TotalPay               0
# TotalPayBenefits       0
# Year                   0
# Notes               1000
# Agency                 0
# Status              1000
# dtype: int64

# %%
data1 = data.dropna()
#temporarily deleting data

# %%
data1.shape
#deleted all rows
# Out:
# (0, 13)

# %%
data.drop(['Benefits', 'Notes', 'Status'], axis = 1, inplace = True)

# %%
data.shape
#null columns got deleted
# Out:
# (1000, 10)

# %%
data.isna().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
data['JobTitle'].unique()
#finding different job title
# Out:
# <StringArray>
# [    'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#                     'CAPTAIN III (POLICE DEPARTMENT)',
#                'WIRE ROPE CABLE MAINTENANCE MECHANIC',
#        'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)',
#                           'ASSISTANT DEPUTY CHIEF II',
#                  'BATTALION CHIEF, (FIRE DEPARTMENT)',
#                      'DEPUTY DIRECTOR OF INVESTMENTS',
#              'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#    'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)',
#                         'EXECUTIVE CONTRACT EMPLOYEE',
#  ...
#  'ELECTRONIC MAINTENANCE TECHNICIAN ASSISTANT SUPERV',
#                                 'CLINICAL PHARMACIST',
#                                  'DEPARTMENT HEAD II',
#                           'CLINICAL NURSE SPECIALIST',
#                                       'NURSE MIDWIFE',
#            'ELECTRICAL TRANSIT MECHANIC SUPERVISOR I',
#                                           'MANAGER V',
# ...

# %%
data['JobTitle'].nunique()
#finding total number of job titles
# Out:
# 113

# %%
data['Agency'].unique()
# Out:
# <StringArray>
# ['San Francisco']
# Length: 1, dtype: str

# %%
data['Year'].unique()
# Out:
# array([2011])

# %%
data[data['OvertimePay']==0]
# Out:
#        Id         EmployeeName  \
# 0       1       NATHANIEL FORD
# 7       8        DAVID KUSHNER
# 9      10   JOANNE HAYES-WHITE
# 12     13    EDWARD HARRINGTON
# 13     14          JOHN MARTIN
# ..    ...                  ...
# 995   996   ANTIONETTE GRIFFIN
# 996   997        KATHERINE MAH
# 997   998  CHRISTINE DAVENPORT
# 998   999          ANNE HUGHES
# 999  1000           JOHN FAZIO
#
#                                            JobTitle    BasePay  OvertimePay  \
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18          0.0
# 7                    DEPUTY DIRECTOR OF INVESTMENTS  256576.96          0.0
# 9            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00          0.0
# 12                      EXECUTIVE CONTRACT EMPLOYEE  294580.02          0.0
# 13                                DEPARTMENT HEAD V  271329.03          0.0
# ..                                              ...        ...          ...
# ...

# %%
data.loc[data['OvertimePay'] == 0, 'Agency'] = 'Texas'
#changing people with 0 overtimepay to texas agency

# %%
### How many - groupby
### How many + counts - value_counts()

# %%
data['Agency'].value_counts()
# Out:
# Agency
# San Francisco    631
# Texas            369
# Name: count, dtype: int64

# %% [markdown]
# # Pie Chart

# %%
plt.pie(data['Agency'].value_counts().values, labels = data['Agency'].value_counts().index, autopct = '%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19a4c7b9010>,
# ...
#  [Text(-0.4400320717219599, 1.0081526550359723, 'San Francisco'),
#   Text(0.44003252040090934, -1.0081524591993136, 'Texas')],
#  [Text(-0.24001749366652353, 0.5499014482014394, '63.10%'),
#   Text(0.24001773840049595, -0.5499013413814436, '36.90%')])

# %%
data['BasePay'].mean()
# Out:
# np.float64(145663.9982)

# %%
result = data.groupby('Agency')['BasePay'].mean()
#show average base pay for each agency

# %%
plt.pie(result.values, labels = result.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x19a50cb7250>,
# ...
#  [Text(0.321256047446596, 1.0520430371325076, 'San Francisco'),
#   Text(-0.3212559554740678, -1.0520430652176003, 'Texas')])

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
#advanced version of matplotlib

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.histplot(data = data, x = 'Sepal_Length', kde = True)
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Count'>

# %%
#In this we need to give total data too and x index and kde gives the distribution curve

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.scatterplot(data = data, x = 'Petal_Length', y = 'Petal_Width', hue = 'Species')
#hue will give color based on column
# Out:
# <Axes: xlabel='Petal_Length', ylabel='Petal_Width'>

# %%
data['Species'].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize = (5,5))
sns.countplot(data = data, x = 'Species')
#countplot is advanced chart which internally does value counts and plot bar chart
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
data = pd.read_csv('cars93.csv')

# %%
data.info()
#first run the cleaned code
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     str
#  1   Model           93 non-null     str
#  2   Type            93 non-null     str
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     str
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), str(4)
# memory usage: 7.4 KB

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
sns.countplot(data = data, x = 'Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
data[['Type', 'AirBags']].value_counts()
# Out:
# Type     AirBags
# Small    Driver only           14
# Midsize  Driver only           13
# Compact  Driver only           10
# Sporty   Driver only            9
# Midsize  Driver & Passenger     8
# Large    Driver only            7
# Sporty   Driver & Passenger     4
# Van      Driver only            4
# Large    Driver & Passenger     4
# Compact  Driver & Passenger     3
# Van      Driver & Passenger     3
# Name: count, dtype: int64

# %%
sns.countplot(data = data, x = 'Type', hue = 'AirBags')
#if we have one and more categorical column use hue
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# Q.Find out average mileage for each type of car

# %%
data['MPG.city'].mean()
# Out:
# np.float64(22.365591397849464)

# %%
data.groupby('Type')['MPG.city'].mean()
# Out:
# Type
# Compact    22.687500
# Large      18.363636
# Midsize    19.545455
# Small      29.857143
# Sporty     21.785714
# Van        17.000000
# Name: MPG.city, dtype: float64

# %%
sns.barplot(data = data, x = 'Type', y = 'MPG.city')
#barplot will automatically calculate mean
# Out:
# <Axes: xlabel='Type', ylabel='MPG.city'>

# %%
#run Iris dataset

# %%
plt.figure(figsize = (5,5))
sns.pairplot(data = data)
#it will show columns relationship with every other column

# %%
plt.figure(figsize = (5,5))
sns.pairplot(data = data, hue = 'Species')
